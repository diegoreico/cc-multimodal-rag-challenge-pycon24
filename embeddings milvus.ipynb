# %%
# !pip install --upgrade pymilvus==2.4.5 "pymilvus[model]"
# Out:
# Collecting pymilvus==2.4.5
#   Using cached pymilvus-2.4.5-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools>69 in ./env/lib/python3.11/site-packages (from pymilvus==2.4.5) (75.1.0)
# Requirement already satisfied: grpcio<=1.63.0,>=1.49.1 in ./env/lib/python3.11/site-packages (from pymilvus==2.4.5) (1.63.0)
# Requirement already satisfied: protobuf>=3.20.0 in ./env/lib/python3.11/site-packages (from pymilvus==2.4.5) (4.25.5)
# Requirement already satisfied: environs<=9.5.0 in ./env/lib/python3.11/site-packages (from pymilvus==2.4.5) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in ./env/lib/python3.11/site-packages (from pymilvus==2.4.5) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in ./env/lib/python3.11/site-packages (from pymilvus==2.4.5) (2.2.3)
# Requirement already satisfied: milvus-lite<2.5.0,>=2.4.0 in ./env/lib/python3.11/site-packages (from pymilvus==2.4.5) (2.4.10)
# Requirement already satisfied: milvus-model>=0.1.0 in ./env/lib/python3.11/site-packages (from pymilvus[model]) (0.2.7)
# Requirement already satisfied: marshmallow>=3.0.0 in ./env/lib/python3.11/site-packages (from environs<=9.5.0->pymilvus==2.4.5) (3.22.0)
# Requirement already satisfied: python-dotenv in ./env/lib/python3.11/site-packages (from environs<=9.5.0->pymilvus==2.4.5) (1.0.1)
# Requirement already satisfied: tqdm in ./env/lib/python3.11/site-packages (from milvus-lite<2.5.0,>=2.4.0->pymilvus==2.4.5) (4.66.5)
# Requirement already satisfied: transformers>=4.36.0 in ./env/lib/python3.11/site-packages (from milvus-model>=0.1.0->pymilvus[model]) (4.45.1)
# Requirement already satisfied: onnxruntime in ./env/lib/python3.11/site-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.19.2)
# Requirement already satisfied: scipy>=1.10.0 in ./env/lib/python3.11/site-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.14.1)
# Requirement already satisfied: numpy in ./env/lib/python3.11/site-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.11/site-packages (from pandas>=1.2.4->pymilvus==2.4.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.11/site-packages (from pandas>=1.2.4->pymilvus==2.4.5) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib/python3.11/site-packages (from pandas>=1.2.4->pymilvus==2.4.5) (2024.2)
# Requirement already satisfied: packaging>=17.0 in ./env/lib/python3.11/site-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus==2.4.5) (24.1)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus==2.4.5) (1.16.0)
# Requirement already satisfied: filelock in ./env/lib/python3.11/site-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in ./env/lib/python3.11/site-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.25.1)
# Requirement already satisfied: pyyaml>=5.1 in ./env/lib/python3.11/site-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./env/lib/python3.11/site-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.9.11)
# Requirement already satisfied: requests in ./env/lib/python3.11/site-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in ./env/lib/python3.11/site-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in ./env/lib/python3.11/site-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.20.0)
# Requirement already satisfied: coloredlogs in ./env/lib/python3.11/site-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (15.0.1)
# Requirement already satisfied: flatbuffers in ./env/lib/python3.11/site-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (24.3.25)
# Requirement already satisfied: sympy in ./env/lib/python3.11/site-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (1.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (4.12.2)
# Requirement already satisfied: humanfriendly>=9.1 in ./env/lib/python3.11/site-packages (from coloredlogs->onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.11/site-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.11/site-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.11/site-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.11/site-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./env/lib/python3.11/site-packages (from sympy->onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (1.3.0)
# Using cached pymilvus-2.4.5-py3-none-any.whl (197 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.4.7
#     Uninstalling pymilvus-2.4.7:
#       Successfully uninstalled pymilvus-2.4.7
# Successfully installed pymilvus-2.4.5

# %%
# !pip remove pymilvus
# Out:
# ERROR: unknown command "remove"

# %%
# !pip freeze | grep pymilvus
# Out:
# pymilvus==2.4.5

# %%
 # !pip install -U pymilvus
# Out:
# Requirement already satisfied: pymilvus in ./env/lib/python3.11/site-packages (2.4.5)
# Collecting pymilvus
#   Using cached pymilvus-2.4.7-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools>69 in ./env/lib/python3.11/site-packages (from pymilvus) (75.1.0)
# Requirement already satisfied: grpcio>=1.49.1 in ./env/lib/python3.11/site-packages (from pymilvus) (1.63.0)
# Requirement already satisfied: protobuf>=3.20.0 in ./env/lib/python3.11/site-packages (from pymilvus) (4.25.5)
# Requirement already satisfied: environs<=9.5.0 in ./env/lib/python3.11/site-packages (from pymilvus) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in ./env/lib/python3.11/site-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in ./env/lib/python3.11/site-packages (from pymilvus) (2.2.3)
# Requirement already satisfied: milvus-lite<2.5.0,>=2.4.0 in ./env/lib/python3.11/site-packages (from pymilvus) (2.4.10)
# Requirement already satisfied: marshmallow>=3.0.0 in ./env/lib/python3.11/site-packages (from environs<=9.5.0->pymilvus) (3.22.0)
# Requirement already satisfied: python-dotenv in ./env/lib/python3.11/site-packages (from environs<=9.5.0->pymilvus) (1.0.1)
# Requirement already satisfied: tqdm in ./env/lib/python3.11/site-packages (from milvus-lite<2.5.0,>=2.4.0->pymilvus) (4.66.5)
# Requirement already satisfied: numpy>=1.23.2 in ./env/lib/python3.11/site-packages (from pandas>=1.2.4->pymilvus) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.11/site-packages (from pandas>=1.2.4->pymilvus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.11/site-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib/python3.11/site-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: packaging>=17.0 in ./env/lib/python3.11/site-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus) (24.1)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.16.0)
# Using cached pymilvus-2.4.7-py3-none-any.whl (198 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.4.5
#     Uninstalling pymilvus-2.4.5:
#       Successfully uninstalled pymilvus-2.4.5
# Successfully installed pymilvus-2.4.7

# %%
import pandas as pd

# %%
data = pd.read_csv('data_with_image_descriptions.csv')

data
# Out:
#       Unnamed: 0                                     reviewed claim  \
# 0              0  reviewed claim: Dióxido de cloro ayuda a sanar...
# 1              1  reviewed claim: El dióxido de cloro tiene prop...
# 2              2  reviewed claim: Centenas de pilotos de avião p...
# 3              3  reviewed claim: Delta Pilots In Video Were Pro...
# 4              4  reviewed claim: Des pilotes de Delta Airlines ...
# ...          ...                                                ...
# 3863        3863  reviewed claim: “Mejores salarios, menos impue...
# 3864        3864  reviewed claim: Video muestra el robo de un ve...
# 3865        3865  reviewed claim: Si ganas un dólar al año, paga...
# 3866        3866  reviewed claim: “Somos el país que más ha incr...
# 3867        3867  reviewed claim: Petor dijo que las iglesias de...
#
#                                        unverified claim  \
# 0     unverified claim: El dióxido de cloro ayuda a ...
# 1     unverified claim: El dióxido de cloro ayuda a ...
# 2     unverified claim: Pilotos de aviación se manif...
# 3     unverified claim: Pilotos de aviación se manif...
# 4     unverified claim: Pilotos de aviación se manif...
# ...                                                 ...
# 3863  unverified claim: el 50% del deposito de cualq...
# 3864  unverified claim: el 50% del deposito de cualq...
# 3865  unverified claim: el 50% del deposito de cualq...
# 3866  unverified claim: el 50% del deposito de cualq...
# 3867  unverified claim: el 50% del deposito de cualq...
#
#                    similarity        country lang       author name  \
# 0     Both claims are similar         Mexico   es       AFP Factual
# 1     Both claims are similar          Spain   es      Europa Press
# 2     Both claims are similar       Portugal   pt  Polígrafo - SAPO
# 3     Both claims are similar  United States   en      Lead Stories
# 4     Both claims are similar         France   fr       AFP Factuel
# ...                       ...            ...  ...               ...
# 3863   Claims are not similar         Mexico   es       AFP Factual
# 3864   Claims are not similar         Mexico   es       AFP Factual
# 3865   Claims are not similar         Mexico   es       AFP Factual
# 3866   Claims are not similar            NaN   es           Newtral
# 3867   Claims are not similar       Colombia   es     ColombiaCheck
#
#                                   cr_item_reviewed_text  \
# 0     Dióxido de cloro ayuda a sanar esclerosis múlt...
# 1       El dióxido de cloro tiene propiedades curativas
# 2     Centenas de pilotos de avião protestam contra ...
# 3     Delta Pilots In Video Were Protesting COVID-19...
# 4     Des pilotes de Delta Airlines manifestent cont...
# ...                                                 ...
# 3863  “Mejores salarios, menos impuestos", dice vall...
# 3864      Video muestra el robo de un vehículo en Quito
# 3865  Si ganas un dólar al año, pagas 60 dólares de ...
# 3866  “Somos el país que más ha incrementado los imp...
# 3867  Petor dijo que las iglesias deben tener contro...
#
#                                                cr_image  \
# 0     https://factual.afp.com/sites/default/files/st...
# 1     https://img.europapress.es/fotoweb/fotonoticia...
# 2     https://thumbs.web.sapo.io/?W=1200&H=630&delay...
# 3           https://leadstories.com/caption_3479196.jpg
# 4     https://factuel.afp.com/sites/default/files/st...
# ...                                                 ...
# 3863  https://factual.afp.com/sites/default/files/st...
# 3864  https://factual.afp.com/sites/default/files/st...
# 3865  https://factual.afp.com/sites/default/files/st...
# 3866                                                NaN
# 3867  https://colombiacheck.s3.us-east-2.amazonaws.c...
#
#                                        local_image_path  \
# 0                                                   NaN
# 1     cr_images/06700810-4374-73d2-8000-e477c442f105...
# 2        cr_images/06700810-4e14-75a7-8000-56f45415027b
# 3     cr_images/06700810-5781-71ed-8000-140fe51b8d46...
# 4                                                   NaN
# ...                                                 ...
# 3863                                                NaN
# 3864                                                NaN
# 3865                                                NaN
# 3866                                                NaN
# 3867  cr_images/0670085c-6fa5-7d45-8000-d3f4fc444776...
#
#                                                  claims  \
# 0     reviewed claim: Dióxido de cloro ayuda a sanar...
# 1     reviewed claim: El dióxido de cloro tiene prop...
# 2     reviewed claim: Centenas de pilotos de avião p...
# 3     reviewed claim: Delta Pilots In Video Were Pro...
# 4     reviewed claim: Des pilotes de Delta Airlines ...
# ...                                                 ...
# 3863  reviewed claim: “Mejores salarios, menos impue...
# 3864  reviewed claim: Video muestra el robo de un ve...
# 3865  reviewed claim: Si ganas un dólar al año, paga...
# 3866  reviewed claim: “Somos el país que más ha incr...
# 3867  reviewed claim: Petor dijo que las iglesias de...
#
#                                       image_description
# 0                                                   NaN
# 1     The image depicts a laboratory setting where a...
# 2     The image depicts a group of airline pilots st...
# 3     The image depicts a scene of a protest, likely...
# 4                                                   NaN
# ...                                                 ...
# 3863                                                NaN
# 3864                                                NaN
# 3865                                                NaN
# 3866                                                NaN
# 3867  The image features a prominent figure, likely ...
#
# [3868 rows x 12 columns]

# %%
data['local_image_path'].fillna('').apply(lambda x: len(x) > 0).value_counts()
# Out:
# local_image_path
# False    2011
# True     1857
# Name: count, dtype: int64

# %%
data['image_description'].fillna('').apply(lambda x: len(x) > 0).value_counts()
# Out:
# image_description
# False    2022
# True     1846
# Name: count, dtype: int64

# %%
data['image_description'][11]
# Out:
# 'The image features a split-screen composition. On the left side, a news anchor, presumably Anderson Cooper, is seen delivering a news segment. He has a serious expression and is dressed in a dark suit with a light-colored shirt. The background is a blurred newsroom setting, suggesting a live broadcast.\n\nOn the right side of the image, there is a close-up of a person\'s arm, which appears to show signs of distress or a medical condition, possibly related to myocarditis. The skin tone is light, and the arm is partially obscured, focusing on the area that seems affected.\n\nOverlaying the entire image is a bold, red "FAKE" stamp, indicating that the information being presented may be misleading or false. The text at the bottom of the image reads "BREAKING NEWS" and includes a headline stating "UKRAINE INVASION CAUSING MYOCARDITIS," along with a timestamp indicating it is live news.\n\nThe overall tone of the image suggests a critical examination of the news being reported, emphasizing the potential for misinformation. The contrasting elements of the news anchor and the medical imagery create a sense of urgency and concern regarding the topic being discussed.'

# %%
data['image_description'] = data['image_description'].fillna('').apply(lambda x: 'Related Image: '+x if len(x) > 1 else '')
data['text'] = data['claims'] + '\n' + data['similarity'] + '\nRelated image description: ' + data['image_description']

# %%
data = data[data['text'].fillna('').apply(len) > 1]
country_list = list(data['country'].fillna("Unknown"))
author_name_list = list(data['author name'].fillna("Unknown"))
image_paths_list = list(data['local_image_path'].fillna(''))

# %%
docs = list(data['text'])
docs[:3]
# Out:
# ['reviewed claim: Dióxido de cloro ayuda a sanar esclerosis múltiple, ela y otras patologías\nunverified claim: El dióxido de cloro ayuda a sanar la esclerósis múltiple\nBoth claims are similar',
#  "reviewed claim: El dióxido de cloro tiene propiedades curativas\nunverified claim: El dióxido de cloro ayuda a sanar la esclerósis múltiple\nBoth claims are similarRelated Image: The image depicts a laboratory setting where a scientist is engaged in an experiment. The main focus is on a male scientist, who is wearing protective gear, including safety goggles, a face mask, and blue gloves. He is intently looking at a pipette as he prepares to add a liquid to a series of test tubes arranged in a rack in front of him.\n\nThe background features a blurred laboratory environment, suggesting a professional and sterile atmosphere. The test tubes contain various colored liquids, predominantly shades of blue, green, and purple, indicating different chemical substances. The scientist's concentration is evident as he carefully controls the pipette, highlighting the precision required in scientific work.\n\nIn the foreground, several flasks and beakers are visible, each containing liquids of different colors, contributing to the vibrant and dynamic feel of the scene. The overall composition emphasizes the meticulous nature of laboratory work, showcasing both the equipment and the scientist's focused demeanor.",
#  'reviewed claim: Centenas de pilotos de avião protestam contra vacinas Covid-19 no aeroporto de Atlanta.\nunverified claim: Pilotos de aviación se manifiestan en un aeropuerto en contra a la vacunación obligatoria contra el covid-19\nBoth claims are similarRelated Image: The image depicts a group of airline pilots standing in a line, likely participating in a protest or demonstration. They are dressed in formal pilot uniforms, which typically include white shirts, ties, and dark trousers. Many of the pilots are wearing green and blue lanyards, possibly indicating their affiliation with a union or organization.\n\nEach pilot is holding a sign that conveys messages related to their demands, such as calls for a new contract or better working conditions. The signs are colorful and feature bold text, emphasizing their demands for industry-leading contracts and readiness to strike if necessary.\n\nThe setting appears to be outdoors, likely at an airport or a similar location, with a clear blue sky overhead. The background includes a structure that suggests an airport terminal or a similar facility. The composition of the image highlights the solidarity among the pilots, as they stand together in a unified stance, facing the camera. The overall atmosphere conveys a sense of determination and collective action.']

# %%
data['text'].apply(len).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
import torch
DIMENSION=2048
# Load the embedding model with the last layer removed
model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', pretrained=True)
model = torch.nn.Sequential(*(list(model.children())[:-1]))
model.eval()
# Out:
# Using cache found in /home/dreiriz/.cache/torch/hub/pytorch_vision_v0.10.0
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (5): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (6): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (7): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
from torchvision import transforms

# Preprocessing for images
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
from PIL import Image
import glob
from tqdm import tqdm

def embed(data):
    with torch.no_grad():
        ret = model(torch.stack(data))
        # If more than one image, use squeeze
        if len(ret) > 1:
            return ret.squeeze().tolist()[0]
        # Squeeze would remove batch for single image, so using flatten
        else:
            return torch.flatten(ret, start_dim=1).tolist()[0]


# Get the filepaths of the images
paths = glob.glob('./cr_images/*', recursive=True)
dict_img_embd = {}

for path in tqdm(paths):
    try:
        im = Image.open(path).convert('RGB')
        result = preprocess(im)
        result = embed([result])
        file_name = path.split("cr_images/")[1]
        dict_img_embd[file_name] = result
        #    data_batch = [[],[]]
    except:
        print("Error processing image")
# Out:
#   0%|          | 2/1860 [00:00<05:22,  5.75it/s]
# Error processing image
#   7%|▋         | 126/1860 [00:11<02:37, 10.99it/s]/home/dreiriz/Descargas/multimodal_rag_dataset.csv/env/lib/python3.11/site-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  20%|█▉        | 365/1860 [00:30<01:35, 15.62it/s]
# Error processing image
#  21%|██        | 393/1860 [00:32<01:54, 12.77it/s]
# Error processing image
#  23%|██▎       | 431/1860 [00:36<01:51, 12.79it/s]
# Error processing image
#  24%|██▎       | 438/1860 [00:36<01:34, 15.00it/s]
# Error processing image
#  29%|██▊       | 534/1860 [00:44<01:42, 12.89it/s]
# Error processing image
#  31%|███▏      | 583/1860 [00:47<01:27, 14.53it/s]
# Error processing image
#  53%|█████▎    | 992/1860 [01:20<00:55, 15.62it/s]
# Error processing image
#  55%|█████▌    | 1027/1860 [01:23<00:57, 14.51it/s]
# Error processing image
#  58%|█████▊    | 1080/1860 [01:27<00:49, 15.75it/s]
# Error processing image
#  83%|████████▎ | 1541/1860 [02:04<00:22, 14.22it/s]
# Error processing image
# 100%|██████████| 1860/1860 [02:30<00:00, 12.38it/s]

# %%
image_vector = data['local_image_path'].fillna('').apply(lambda x: x.replace("cr_images/","")).apply(lambda x: dict_img_embd[x] if x in dict_img_embd else None)

# %%
from milvus_model.hybrid import BGEM3EmbeddingFunction

ef = BGEM3EmbeddingFunction(use_fp16=False, device="cpu")
dense_dim = ef.dim["dense"]

# Generate embeddings using BGE-M3 model
docs_embeddings = ef(docs)
# Out:
# Fetching 30 files:   0%|          | 0/30 [00:00<?, ?it/s]
# /home/dreiriz/Descargas/multimodal_rag_dataset.csv/env/lib/python3.11/site-packages/FlagEmbedding/BGE_M3/modeling.py:335: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   colbert_state_dict = torch.load(os.path.join(model_dir, 'colbert_linear.pt'), map_location='cpu')
# /home/dreiriz/Descargas/multimodal_rag_dataset.csv/env/lib/python3.11/site-packages/FlagEmbedding/BGE_M3/modeling.py:336: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   sparse_state_dict = torch.load(os.path.join(model_dir, 'sparse_linear.pt'), map_location='cpu')
# Inference Embeddings: 100%|██████████| 242/242 [56:29<00:00, 14.01s/it]

# %%
try:
    connections.disconnect("default")
except:
    print("Can't disconnect")

try:
    client.disconnect("default")
except:
    print("Can't disconnect")
# Out:
# Can't disconnect
# Can't disconnect

# %%
milvus_db = "milvus_demo_5.db"
milvus_collection = milvus_db.split(".")[0]

# %%
from pymilvus import MilvusClient

client = MilvusClient(milvus_db)

# %%
if client.has_collection(collection_name=milvus_collection):
    client.drop_collection(collection_name=milvus_collection)

# %%
from pymilvus import (
    connections,
    utility,
    FieldSchema,
    CollectionSchema,
    DataType,
    Collection,
)
# Specify the data schema for the new Collection
fields = [
    # Use auto generated id as primary key
    FieldSchema(
        name="pk", dtype=DataType.VARCHAR, is_primary=True, auto_id=True, max_length=100
    ),
    # Store the original text to retrieve based on semantically distance
    FieldSchema(name="text", dtype=DataType.VARCHAR, max_length=3000),
    # Milvus now supports both sparse and dense vectors,
    # we can store each in a separatdir(e field to conduct hybrid search on both vectors
    #FieldSchema(name="sparse_vector", dtype=DataType.SPARSE_FLOAT_VECTOR),
    FieldSchema(name="dense_vector", dtype=DataType.FLOAT_VECTOR, dim=dense_dim),
    FieldSchema(name="image_vector", dtype=DataType.FLOAT_VECTOR, dim=DIMENSION),
    FieldSchema(name="local_image", dtype=DataType.VARCHAR, max_length=512),
    FieldSchema(name="country", dtype=DataType.VARCHAR, max_length=512),
    FieldSchema(name="author_name", dtype=DataType.VARCHAR, max_length=512)
]
schema = CollectionSchema(fields, enable_dynamic_field=True)

# %%
index_params = client.prepare_index_params()

# index_params.add_index(
#     field_name="sparse_vector",
#     index_type="SPARSE_INVERTED_INDEX",
#     metric_type="IP"
# )

index_params.add_index(
    field_name="dense_vector", 
    index_type="AUTOINDEX",
    metric_type="IP",
)

index_params.add_index(
    field_name="image_vector", 
    index_type="AUTOINDEX",
    metric_type="L2"
)

# %%
import time
client.create_collection(
    collection_name=milvus_collection,
    schema=schema,
    index_params=index_params
)

# %%
res = client.get_load_state(
    collection_name=milvus_collection
)

print(res)
# Out:
# {'state': <LoadState: Loaded>}

# %%
print(res)
# Out:
# {'state': <LoadState: Loaded>}

# %%
type(docs[0])
# Out:
# str

# %%
type(docs_embeddings["dense"][0])
# Out:
# numpy.ndarray

# %%
type(docs_embeddings["sparse"].toarray()[0])
# Out:
# numpy.ndarray

# %%
type(image_paths_list[0])
# Out:
# str

# %%
len(docs)
# Out:
# 3865

# %%
len(docs_embeddings["dense"])
# Out:
# 3865

# %%
len(image_vector)
# Out:
# 3865

# %%
len(image_paths_list)
# Out:
# 3865

# %%
len(country_list)
# Out:
# 3865

# %%
len(author_name_list)
# Out:
# 3865

# %%
author_name_list[i]
# Out:
# 'AFP Factual'

# %%
image_vector = [ [.0]*DIMENSION if vector is None else vector for vector in image_vector]

for i in range(0, len(docs)):
    insert_data = {
        'text': docs[i],
        #'sparse_vector': docs_embeddings["sparse"][0,:],
        'dense_vector': docs_embeddings["dense"][i],
        'image_vector':image_vector[i],
        'local_image': image_paths_list[i],
        'country': country_list[i],
        'author_name': author_name_list[i],
     }


    client.insert(collection_name=milvus_collection, data=insert_data)

# %%
#client.insert(collection_name=milvus_collection , data = [insert_data])

# %%
from tqdm import tqdm

# %%
# For efficiency, we insert 50 records in each small batch
# for i in tqdm(range(0, len(docs), 50)):
#     batched_entities = [
#         docs[i : i + 50],
#         docs_embeddings["sparse"][i : i + 50],
#         docs_embeddings["dense"][i : i + 50],
#         image_paths_list[i : i + 50],
#     ]
#    
#     col.insert(batched_entities)
# print("Number of entities inserted:", col.num_entities)

# %%
# Enter your search query
query = "La reina Isabel II alimenta niños como animales"

# Generate embeddings for the query
query_embeddings = ef([query])
# print(query_embeddings)

# %%
from pymilvus import (
    AnnSearchRequest,
    WeightedRanker,
)


def dense_search(col, query_dense_embedding, limit=10):
    search_params = {
        "metric_type": "IP",
        "params": {
            "radius": 0.6,
        }}
    res = client.search(
        collection_name=milvus_collection,
        data=[query_dense_embedding],
        anns_field=col,
        limit=limit,
        output_fields=["text","local_image"],
        search_params=search_params,
        
    )
    return res[0]


def sparse_search(col, query_sparse_embedding, limit=10):
    search_params = {
        "metric_type": "IP",
        "params": {
            "radius": 0.8,
        },
    }
    res = connection.search(
        [query_sparse_embedding],
        anns_field="sparse_vector",
        limit=limit,
        output_fields=["text",""],
        param=search_params,
    )[0]
    return res


def hybrid_search(
    col,
    query_dense_embedding,
    query_sparse_embedding,
    sparse_weight=1.0,
    dense_weight=1.0,
    limit=10,
):
    dense_search_params = {"metric_type": "IP", "params": {}}
    dense_req = AnnSearchRequest(
        [query_dense_embedding], "dense_vector", dense_search_params, limit=limit
    )
    sparse_search_params = {"metric_type": "IP", "params": {}}
    sparse_req = AnnSearchRequest(
        [query_sparse_embedding], "sparse_vector", sparse_search_params, limit=limit
    )
    rerank = WeightedRanker(sparse_weight, dense_weight)
    res = col.hybrid_search(
        [sparse_req, dense_req], rerank=rerank, limit=limit, output_fields=["text"], radius=0.7
    )[0]
    return res

# %%
dense_results = dense_search("dense_vector", query_embeddings["dense"][0])
# sparse_results = sparse_search(col, query_embeddings["sparse"][[0]])
# hybrid_results = hybrid_search(
#     col,
#     query_embeddings["dense"][0],
#     query_embeddings["sparse"][[0]],
#     sparse_weight=0.7,
#     dense_weight=1.0,
# )

# %%
dense_results
# Out:
# [{'id': '453028464095923382',
#   'distance': 0.7119965553283691,
#   'entity': {'local_image': 'cr_images/06700811-c8d8-7fcd-8000-365629d8cae7.jpg',
#    'text': 'reviewed claim: La reina Isabel II arroja comida a un grupo de niños hambrientos en una colonia británica como si fueran animales, según muestra una antigua grabación.\nunverified claim: La reina Isabel II arroja comida a niños africanos\nBoth claims are similarRelated Image: The image features a woman with a warm smile, wearing a striking turquoise hat adorned with decorative feathers. Her outfit is also in a matching shade of turquoise, complemented by a pearl necklace and a brooch on her left side. The background includes a figure in military attire, suggesting a formal or ceremonial setting. The overall composition highlights the woman as the focal point, with her vibrant attire contrasting against the more subdued colors of the military uniform behind her. The scene conveys a sense of elegance and formality, likely during an official event.'}},
#  {'id': '453028377162416302',
#   'distance': 0.7119965553283691,
#   'entity': {'local_image': 'cr_images/06700811-c8d8-7fcd-8000-365629d8cae7.jpg',
#    'text': 'reviewed claim: La reina Isabel II arroja comida a un grupo de niños hambrientos en una colonia británica como si fueran animales, según muestra una antigua grabación.\nunverified claim: La reina Isabel II arroja comida a niños africanos\nBoth claims are similarRelated Image: The image features a woman with a warm smile, wearing a striking turquoise hat adorned with decorative feathers. Her outfit is also in a matching shade of turquoise, complemented by a pearl necklace and a brooch on her left side. The background includes a figure in military attire, suggesting a formal or ceremonial setting. The overall composition highlights the woman as the focal point, with her vibrant attire contrasting against the more subdued colors of the military uniform behind her. The scene conveys a sense of elegance and formality, likely during an official event.'}},
#  {'id': '453028464086486172',
#   'distance': 0.6985856294631958,
#   'entity': {'local_image': 'cr_images/06700811-92ec-7e09-8000-c4eb1d403e24.jpg',
#    'text': 'reviewed claim: La reina Isabel II arroja comida a un grupo de niños hambrientos en una colonia británica como si fueran animales, según muestra una antigua grabación.\nunverified claim: La reina Isabel II no es quien sale en este video lanzando monedas a niños asiáticos\nBoth claims are similarRelated Image: The image features a woman with a warm smile, wearing a striking turquoise hat adorned with decorative feathers. She is dressed in a matching turquoise outfit, which has a textured pattern, and is accessorized with a pearl necklace and a brooch on her left side. Her hair is styled neatly, complementing her overall elegant appearance.\n\nIn the background, there is a figure in military attire, suggesting a formal or ceremonial context. The individual in uniform is partially visible, indicating a setting that may involve an official event or gathering. The overall composition highlights the woman as the focal point, with the background figure adding context to the scene. The colors are vibrant, and the expressions convey a sense of positivity and engagement.'}},
#  {'id': '453028377150619796',
#   'distance': 0.6985856294631958,
#   'entity': {'local_image': 'cr_images/06700811-92ec-7e09-8000-c4eb1d403e24.jpg',
#    'text': 'reviewed claim: La reina Isabel II arroja comida a un grupo de niños hambrientos en una colonia británica como si fueran animales, según muestra una antigua grabación.\nunverified claim: La reina Isabel II no es quien sale en este video lanzando monedas a niños asiáticos\nBoth claims are similarRelated Image: The image features a woman with a warm smile, wearing a striking turquoise hat adorned with decorative feathers. She is dressed in a matching turquoise outfit, which has a textured pattern, and is accessorized with a pearl necklace and a brooch on her left side. Her hair is styled neatly, complementing her overall elegant appearance.\n\nIn the background, there is a figure in military attire, suggesting a formal or ceremonial context. The individual in uniform is partially visible, indicating a setting that may involve an official event or gathering. The overall composition highlights the woman as the focal point, with the background figure adding context to the scene. The colors are vibrant, and the expressions convey a sense of positivity and engagement.'}},
#  {'id': '453028464097758394',
#   'distance': 0.6922672390937805,
#   'entity': {'local_image': '',
#    'text': 'reviewed claim: La reina Isabel II, alimentando niños seres humanos como pollos en un patio\nunverified claim: La reina Isabel II arroja comida a niños africanos\nBoth claims are similar'}},
#  {'id': '453028377164251314',
#   'distance': 0.6922672390937805,
#   'entity': {'local_image': '',
#    'text': 'reviewed claim: La reina Isabel II, alimentando niños seres humanos como pollos en un patio\nunverified claim: La reina Isabel II arroja comida a niños africanos\nBoth claims are similar'}},
#  {'id': '453028464087272606',
#   'distance': 0.6872718334197998,
#   'entity': {'local_image': '',
#    'text': 'reviewed claim: La reine Elisabeth II nourrit des enfants noirs comme des poulets\nunverified claim: La reina Isabel II no es quien sale en este video lanzando monedas a niños asiáticos\nBoth claims are similar'}},
#  {'id': '453028377151406230',
#   'distance': 0.6872718334197998,
#   'entity': {'local_image': '',
#    'text': 'reviewed claim: La reine Elisabeth II nourrit des enfants noirs comme des poulets\nunverified claim: La reina Isabel II no es quien sale en este video lanzando monedas a niños asiáticos\nBoth claims are similar'}},
#  {'id': '453028464088583330',
#   'distance': 0.680314302444458,
#   'entity': {'local_image': '',
#    'text': 'reviewed claim: La reina Isabel II, alimentando niños seres humanos como pollos en un patio\nunverified claim: La reina Isabel II no es quien sale en este video lanzando monedas a niños asiáticos\nBoth claims are similar'}},
#  {'id': '453028377153241242',
#   'distance': 0.680314302444458,
#   'entity': {'local_image': '',
#    'text': 'reviewed claim: La reina Isabel II, alimentando niños seres humanos como pollos en un patio\nunverified claim: La reina Isabel II no es quien sale en este video lanzando monedas a niños asiáticos\nBoth claims are similar'}}]

# %%
# Get the filepaths of the images
path = 'cr_images/0670081b-90f3-7e1d-8000-fe15aab25b3a.jpg'

im = Image.open(path).convert('RGB')
result = preprocess(im)
result = embed([result])
result
# Out:
# [0.37293609976768494,
#  0.28792083263397217,
#  1.8536436557769775,
#  0.20296593010425568,
#  0.8890119194984436,
#  0.17210131883621216,
#  0.7894881367683411,
#  0.16243235766887665,
#  0.5100081562995911,
#  1.0255991220474243,
#  0.3555085361003876,
#  0.25921061635017395,
#  0.5569261908531189,
#  0.4062553346157074,
#  0.0874224379658699,
#  0.7402158379554749,
#  0.08037180453538895,
#  0.17621535062789917,
#  0.5732225775718689,
#  0.06159408763051033,
#  0.20339813828468323,
#  0.33895301818847656,
#  0.9162377119064331,
#  0.1316119283437729,
#  0.3274138271808624,
#  0.37246477603912354,
#  0.2521470785140991,
#  0.2094532698392868,
#  0.015442562289536,
#  0.3083289861679077,
#  0.5212715268135071,
#  1.1195257902145386,
#  0.27422672510147095,
#  1.6046769618988037,
#  0.23223178088665009,
#  0.07272826135158539,
#  0.09901752322912216,
#  0.2137439101934433,
#  0.581713855266571,
#  0.09830866754055023,
#  0.6030611395835876,
#  0.7249021530151367,
#  0.828728973865509,
#  0.3720131814479828,
#  0.4031803011894226,
#  0.18449126183986664,
#  0.06607747077941895,
#  1.414993166923523,
#  0.6087345480918884,
#  0.9547966122627258,
#  0.21885424852371216,
#  0.10269361734390259,
#  0.3478032648563385,
#  0.35610949993133545,
#  0.10650938749313354,
#  1.296467661857605,
#  0.14967289566993713,
#  0.2594638764858246,
#  0.24093803763389587,
#  0.2896837592124939,
#  0.9836357831954956,
#  0.041199859231710434,
#  0.5072392225265503,
#  0.26620373129844666,
#  1.5526516437530518,
#  0.4320337474346161,
#  0.25537827610969543,
#  0.5069541335105896,
#  0.13248318433761597,
#  1.3755996227264404,
#  0.2654673159122467,
#  1.181248426437378,
#  1.419094204902649,
#  1.0262261629104614,
#  0.4439755976200104,
#  0.010831777937710285,
#  0.4258562922477722,
#  0.23467634618282318,
#  0.35462135076522827,
#  0.840544581413269,
#  0.03418906778097153,
#  0.6192226409912109,
#  0.0856647863984108,
#  0.566760241985321,
#  0.3036796748638153,
#  0.9073808789253235,
#  0.3106411397457123,
#  0.2089211791753769,
#  0.5861167311668396,
#  0.5585114359855652,
#  0.9782729744911194,
#  0.6228947043418884,
#  0.07897377759218216,
#  0.22289741039276123,
#  0.6262871026992798,
#  0.3281491994857788,
#  0.38368654251098633,
#  0.5633203983306885,
#  0.49233534932136536,
#  0.09774461388587952,
#  0.02086789719760418,
#  0.2560283839702606,
#  1.2426282167434692,
#  0.43630126118659973,
#  0.4077271819114685,
#  0.1783348023891449,
#  0.3087838590145111,
#  0.22173947095870972,
#  0.10982509702444077,
#  0.03392310068011284,
#  0.5135015249252319,
#  0.06266980618238449,
#  0.19772720336914062,
#  0.9914596080780029,
#  0.783989667892456,
#  0.41285333037376404,
#  0.2981656491756439,
#  0.876213550567627,
#  0.02917083166539669,
#  0.1038748100399971,
#  0.12559324502944946,
#  0.058332059532403946,
#  1.289963960647583,
#  0.07991698384284973,
#  0.712184488773346,
#  0.3014392852783203,
#  0.5761934518814087,
#  0.4283706843852997,
#  0.06409721076488495,
#  0.8141858577728271,
#  0.8980399966239929,
#  0.5499436259269714,
#  0.26782065629959106,
#  0.5523564219474792,
#  0.19481618702411652,
#  0.08116035908460617,
#  0.4037703573703766,
#  3.1650047302246094,
#  0.5147832036018372,
#  0.19700978696346283,
#  1.1941707134246826,
#  0.14847944676876068,
#  0.19344152510166168,
#  0.8321183919906616,
#  0.3237641155719757,
#  0.15707643330097198,
#  0.16095112264156342,
#  1.4620355367660522,
#  0.13198517262935638,
#  0.6474639177322388,
#  0.4365469515323639,
#  0.36693495512008667,
#  0.7528234124183655,
#  0.5887898206710815,
#  1.0247606039047241,
#  0.8138289451599121,
#  0.51233971118927,
#  0.2212543934583664,
#  0.29263225197792053,
#  0.12189581245183945,
#  0.17297232151031494,
#  0.5233644247055054,
#  0.14568792283535004,
#  0.5950052738189697,
#  0.5025636553764343,
#  0.22472108900547028,
#  0.22962504625320435,
#  0.24089132249355316,
#  0.46776050329208374,
#  0.2818659842014313,
#  0.9185529351234436,
#  0.3987354338169098,
#  0.2742480933666229,
#  0.00047367429942823946,
#  1.325741171836853,
#  0.39157354831695557,
#  0.5741910338401794,
#  0.8915870189666748,
#  0.2533445954322815,
#  0.40236592292785645,
#  0.42044439911842346,
#  0.28744906187057495,
#  0.5745967030525208,
#  1.0225751399993896,
#  0.22662265598773956,
#  0.33303701877593994,
#  0.40412232279777527,
#  0.23198258876800537,
#  0.1620241403579712,
#  0.24474309384822845,
#  0.18308550119400024,
#  0.048363473266363144,
#  0.835858166217804,
#  0.375866562128067,
#  0.3509448766708374,
#  0.4316370189189911,
#  0.2882159948348999,
#  0.5378417372703552,
#  0.5949251651763916,
#  0.18914207816123962,
#  0.432354211807251,
#  0.42805442214012146,
#  0.49832233786582947,
#  0.2286229282617569,
#  0.2431664615869522,
#  0.36375921964645386,
#  0.3702472448348999,
#  0.15073275566101074,
#  0.3588930368423462,
#  1.278998851776123,
#  0.304422527551651,
#  0.038918450474739075,
#  1.4179401397705078,
#  0.6370241045951843,
#  0.07136843353509903,
#  0.38892656564712524,
#  0.8027826547622681,
#  0.11444389820098877,
#  0.7575101256370544,
#  0.15996628999710083,
#  0.5457397103309631,
#  0.7817109823226929,
#  0.8676015734672546,
#  0.8766312003135681,
#  0.7561744451522827,
#  0.7375947833061218,
#  1.4127833843231201,
#  0.31494003534317017,
#  0.5333740711212158,
#  0.05936474725604057,
#  0.23763078451156616,
#  0.3188595473766327,
#  0.5466114282608032,
#  0.5744119882583618,
#  0.034389082342386246,
#  0.44474512338638306,
#  0.2597293555736542,
#  0.8986998796463013,
#  0.07484160363674164,
#  0.1759117692708969,
#  0.630389392375946,
#  0.4193463623523712,
#  0.4955643117427826,
#  5.478302478790283,
#  0.14504747092723846,
#  0.23128187656402588,
#  0.49398449063301086,
#  0.2801050543785095,
#  1.1237128973007202,
#  1.3192647695541382,
#  0.13188675045967102,
#  1.332747220993042,
#  0.6538429260253906,
#  0.6586207151412964,
#  1.962630033493042,
#  0.6692397594451904,
#  0.5004346370697021,
#  0.10463307052850723,
#  0.33751705288887024,
#  0.1357719451189041,
#  0.5616390109062195,
#  0.8139707446098328,
#  0.08009741455316544,
#  1.717848300933838,
#  0.6371344923973083,
#  0.06466411799192429,
#  0.8449090719223022,
#  0.8806896805763245,
#  0.3618690073490143,
#  0.15721376240253448,
#  1.316623330116272,
#  0.1797962784767151,
#  0.24920500814914703,
#  0.42147964239120483,
#  1.0022220611572266,
#  0.26274046301841736,
#  0.39359068870544434,
#  0.10891026258468628,
#  0.13457542657852173,
#  0.14669404923915863,
#  0.3203992545604706,
#  0.19510354101657867,
#  0.3344729542732239,
#  0.04313075169920921,
#  1.1648313999176025,
#  0.7321439385414124,
#  0.5357557535171509,
#  0.9593033194541931,
#  0.3721350133419037,
#  0.5554739236831665,
#  0.5904533863067627,
#  0.41660425066947937,
#  0.7605851888656616,
#  0.2540720999240875,
#  0.6909401416778564,
#  1.2961547374725342,
#  0.1924336701631546,
#  0.28954824805259705,
#  0.4240799844264984,
#  0.0970342755317688,
#  0.21232135593891144,
#  0.4627367854118347,
#  0.43286439776420593,
#  0.29482266306877136,
#  0.3733140528202057,
#  0.5987574458122253,
#  0.055734239518642426,
#  0.45034217834472656,
#  1.1519875526428223,
#  0.398205429315567,
#  0.07089532166719437,
#  0.7067044973373413,
#  0.36545953154563904,
#  0.25491228699684143,
#  0.5254573822021484,
#  0.29162317514419556,
#  0.12713271379470825,
#  0.19067566096782684,
#  0.4001955986022949,
#  0.5409006476402283,
#  0.07868770509958267,
#  0.32041680812835693,
#  0.9462987780570984,
#  0.38185158371925354,
#  0.059140779078006744,
#  0.06964702904224396,
#  0.3491487205028534,
#  0.6312882900238037,
#  0.3247479498386383,
#  0.7402294874191284,
#  0.11210158467292786,
#  0.15261688828468323,
#  0.003856802824884653,
#  0.17451363801956177,
#  0.25879883766174316,
#  0.6040810942649841,
#  0.5676952004432678,
#  0.6600593328475952,
#  0.4692966938018799,
#  0.3912028968334198,
#  0.14060603082180023,
#  0.36826184391975403,
#  0.4550361931324005,
#  0.7707552313804626,
#  0.3283538818359375,
#  0.8046931028366089,
#  1.5782257318496704,
#  0.28519290685653687,
#  0.18852341175079346,
#  0.08875583857297897,
#  2.0478553771972656,
#  0.19509854912757874,
#  0.779585063457489,
#  0.24449099600315094,
#  0.3790844976902008,
#  0.9456154108047485,
#  0.19205240905284882,
#  0.10552393645048141,
#  0.46377331018447876,
#  0.11230122298002243,
#  0.08126641809940338,
#  0.17979012429714203,
#  0.9620320796966553,
#  0.037875134497880936,
#  0.4461131691932678,
#  0.2289009690284729,
#  0.2610428035259247,
#  1.025115728378296,
#  0.1939164400100708,
#  0.578925371170044,
#  0.5138679146766663,
#  0.123255655169487,
#  0.20072904229164124,
#  0.14332886040210724,
#  0.589363694190979,
#  0.42762163281440735,
#  0.06173815578222275,
#  0.11422614008188248,
#  0.22264398634433746,
#  0.49586057662963867,
#  0.27044135332107544,
#  0.10456641763448715,
#  0.05730743333697319,
#  0.9281947612762451,
#  0.1810358613729477,
#  0.1919824182987213,
#  0.7388714551925659,
#  0.18249081075191498,
#  0.13648267090320587,
#  1.0914559364318848,
#  0.28290337324142456,
#  0.5149123668670654,
#  0.3762300908565521,
#  1.127152681350708,
#  2.580368757247925,
#  0.280843585729599,
#  0.10420963913202286,
#  0.33344340324401855,
#  0.14950285851955414,
#  0.31765517592430115,
#  0.15645067393779755,
#  0.32221123576164246,
#  0.345559298992157,
#  0.4945710301399231,
#  1.6901859045028687,
#  0.3616124093532562,
#  0.49259403347969055,
#  0.8944908380508423,
#  0.30616095662117004,
#  1.6769380569458008,
#  0.405884325504303,
#  0.8278114199638367,
#  0.49798354506492615,
#  0.35943111777305603,
#  0.4124270975589752,
#  0.3768525719642639,
#  0.8238770365715027,
#  0.06747117638587952,
#  0.024761781096458435,
#  0.19401562213897705,
#  0.5773021578788757,
#  0.42950719594955444,
#  0.7951981425285339,
#  0.6296530961990356,
#  0.15212267637252808,
#  0.41573551297187805,
#  0.2565159797668457,
#  0.004201010800898075,
#  0.29958224296569824,
#  0.44242098927497864,
#  0.3841356933116913,
#  0.9315885305404663,
#  1.4637700319290161,
#  0.4738963842391968,
#  0.6369713544845581,
#  0.6568471789360046,
#  0.10668373107910156,
#  0.08453240990638733,
#  0.03086586855351925,
#  0.29163992404937744,
#  0.49613600969314575,
#  1.0793676376342773,
#  0.6816241145133972,
#  0.3061511218547821,
#  0.4737348258495331,
#  0.620418131351471,
#  0.1649530977010727,
#  0.3731519877910614,
#  0.27664077281951904,
#  0.013801533728837967,
#  0.22983352839946747,
#  0.2044585645198822,
#  0.1580178141593933,
#  0.4804275333881378,
#  0.5108914375305176,
#  0.12290598452091217,
#  0.08895515650510788,
#  0.20004794001579285,
#  0.45859524607658386,
#  0.32515832781791687,
#  0.24284109473228455,
#  2.198336601257324,
#  0.11883115768432617,
#  0.6547014117240906,
#  0.016048263758420944,
#  0.08549754321575165,
#  0.2189820408821106,
#  0.35249993205070496,
#  0.5598053336143494,
#  0.4816496670246124,
#  0.36070993542671204,
#  0.13010935485363007,
#  0.17214125394821167,
#  0.14767378568649292,
#  0.700569748878479,
#  0.02818889729678631,
#  0.24417266249656677,
#  2.6734068393707275,
#  0.12095363438129425,
#  1.8134311437606812,
#  0.6157156229019165,
#  0.09295699000358582,
#  0.5932559370994568,
#  0.49520039558410645,
#  1.2367948293685913,
#  0.17313313484191895,
#  0.37534138560295105,
#  0.012984080240130424,
#  0.14708656072616577,
#  0.2201268970966339,
#  1.0559778213500977,
#  0.1899004727602005,
#  0.21356156468391418,
#  0.09819268435239792,
#  0.543668806552887,
#  0.13364453613758087,
#  0.832985520362854,
#  1.5435434579849243,
#  0.21435940265655518,
#  0.115997314453125,
#  1.6586403846740723,
#  0.814088761806488,
#  0.5368973612785339,
#  1.6791132688522339,
#  0.4305883049964905,
#  1.925134301185608,
#  0.5784229636192322,
#  1.8519744873046875,
#  0.4561545252799988,
#  0.29730308055877686,
#  0.08259347826242447,
#  0.0808110162615776,
#  0.0884251594543457,
#  0.6087949872016907,
#  2.8219799995422363,
#  0.37869080901145935,
#  1.0607961416244507,
#  0.21632708609104156,
#  0.8073792457580566,
#  0.3595406413078308,
#  0.6487166881561279,
#  0.09354060888290405,
#  0.10999657958745956,
#  0.2906048595905304,
#  0.38236233592033386,
#  0.08276013284921646,
#  2.335012197494507,
#  0.4435719847679138,
#  0.2606692314147949,
#  0.31458210945129395,
#  0.33947449922561646,
#  0.13048261404037476,
#  0.06347028911113739,
#  0.3281289339065552,
#  0.1271076798439026,
#  0.18065261840820312,
#  0.3231549859046936,
#  0.03420190513134003,
#  0.35624030232429504,
#  0.565528154373169,
#  1.7583369016647339,
#  1.383466124534607,
#  0.5418011546134949,
#  0.0777149423956871,
#  0.07331567257642746,
#  0.6911768317222595,
#  0.6153349876403809,
#  0.32212474942207336,
#  0.33492758870124817,
#  0.7277127504348755,
#  0.10500460118055344,
#  0.043658480048179626,
#  0.20884810388088226,
#  0.4421177804470062,
#  0.9046398997306824,
#  0.31022191047668457,
#  0.10252278298139572,
#  0.028576049953699112,
#  0.9316059947013855,
#  0.4868854284286499,
#  0.4709005653858185,
#  0.6169137954711914,
#  0.30687129497528076,
#  0.3969042897224426,
#  0.6474784016609192,
#  0.15605372190475464,
#  0.3465864658355713,
#  0.7413747310638428,
#  0.5751172304153442,
#  0.6106756329536438,
#  1.1515840291976929,
#  0.9660573601722717,
#  0.08537590503692627,
#  0.40290629863739014,
#  0.3374101221561432,
#  2.3509867191314697,
#  0.19244930148124695,
#  2.4061625003814697,
#  0.039560992270708084,
#  0.2350250780582428,
#  0.47856512665748596,
#  0.0765506699681282,
#  0.3508811593055725,
#  1.1476863622665405,
#  0.24494151771068573,
#  0.6325324177742004,
#  0.17078843712806702,
#  0.3348795771598816,
#  0.7544283866882324,
#  0.4636428952217102,
#  0.6852818727493286,
#  0.9230605363845825,
#  0.39184579253196716,
#  0.23792870342731476,
#  1.0223852396011353,
#  0.8397897481918335,
#  0.6159154176712036,
#  0.6154671311378479,
#  0.6076213121414185,
#  0.7230726480484009,
#  0.42417407035827637,
#  0.4160384237766266,
#  0.37263917922973633,
#  0.24373041093349457,
#  0.39272889494895935,
#  0.5825157761573792,
#  0.10974810272455215,
#  0.31396329402923584,
#  0.24478721618652344,
#  0.3898959755897522,
#  0.4975564181804657,
#  0.4610607326030731,
#  0.3385346829891205,
#  1.745469093322754,
#  0.17208391427993774,
#  0.18307271599769592,
#  0.4731864035129547,
#  0.21462731063365936,
#  0.22156822681427002,
#  0.4218336343765259,
#  0.18233266472816467,
#  0.13570766150951385,
#  0.165000781416893,
#  0.12811440229415894,
#  1.545822024345398,
#  1.121100664138794,
#  0.14885373413562775,
#  0.2649427652359009,
#  0.3968871235847473,
#  0.4917796850204468,
#  0.7248930931091309,
#  1.014163613319397,
#  0.9787928462028503,
#  0.21282660961151123,
#  0.5503582954406738,
#  0.26637911796569824,
#  0.15028910338878632,
#  1.3375489711761475,
#  0.5665952563285828,
#  0.3307788372039795,
#  0.13984379172325134,
#  0.5868174433708191,
#  0.8234012126922607,
#  0.03926490247249603,
#  0.8305549621582031,
#  0.7541533708572388,
#  0.8528572916984558,
#  0.29921406507492065,
#  0.09794557094573975,
#  0.6037565469741821,
#  0.3813263177871704,
#  0.4557216167449951,
#  0.4062136709690094,
#  0.5766729712486267,
#  0.860460102558136,
#  1.1849005222320557,
#  0.05282139778137207,
#  0.6825762391090393,
#  0.814185619354248,
#  0.32376089692115784,
#  0.2244451344013214,
#  0.8331084847450256,
#  0.46001434326171875,
#  0.9701761603355408,
#  0.08093362301588058,
#  0.39129185676574707,
#  0.8424021005630493,
#  2.6037580966949463,
#  0.34281376004219055,
#  0.44390541315078735,
#  0.44596847891807556,
#  0.20677469670772552,
#  0.22390496730804443,
#  0.8246274590492249,
#  0.6478520035743713,
#  0.22443434596061707,
#  0.026190320029854774,
#  0.36966222524642944,
#  0.5616701245307922,
#  0.046979982405900955,
#  0.4845419228076935,
#  0.7557080388069153,
#  0.20720113813877106,
#  0.2474859058856964,
#  0.8902773261070251,
#  0.16978539526462555,
#  0.48386356234550476,
#  0.3502834141254425,
#  0.04550040140748024,
#  0.1981147825717926,
#  0.5440648198127747,
#  0.6919150948524475,
#  1.0565704107284546,
#  0.15507110953330994,
#  0.647996187210083,
#  0.45891430974006653,
#  0.03154880180954933,
#  0.420457124710083,
#  0.04036116600036621,
#  0.40425872802734375,
#  0.08498544245958328,
#  0.01494542881846428,
#  0.09514537453651428,
#  0.37982842326164246,
#  0.1947305053472519,
#  0.03338116407394409,
#  0.7364568114280701,
#  0.14456807076931,
#  0.4723323881626129,
#  0.44913461804389954,
#  0.13532277941703796,
#  0.34966468811035156,
#  0.26037171483039856,
#  0.286136269569397,
#  0.024214686825871468,
#  0.10898115485906601,
#  0.03354298695921898,
#  0.13445572555065155,
#  0.7428512573242188,
#  0.22135606408119202,
#  0.19277822971343994,
#  0.0312945656478405,
#  1.100387454032898,
#  0.8891309499740601,
#  1.256039023399353,
#  0.730463445186615,
#  0.1417914777994156,
#  0.050363827496767044,
#  0.3776824474334717,
#  0.2612053155899048,
#  1.006091594696045,
#  1.2674592733383179,
#  0.1678057312965393,
#  0.7057190537452698,
#  0.5305593609809875,
#  0.4457550048828125,
#  0.008807689882814884,
#  0.4437572956085205,
#  0.5711666345596313,
#  0.016143646091222763,
#  0.35151851177215576,
#  1.6980749368667603,
#  0.450046569108963,
#  0.17854338884353638,
#  0.44806337356567383,
#  0.10883786529302597,
#  0.35590019822120667,
#  0.06774942576885223,
#  0.579393744468689,
#  0.10546845942735672,
#  0.31677284836769104,
#  0.4803410470485687,
#  0.038853906095027924,
#  0.5124911069869995,
#  0.24611163139343262,
#  0.29028862714767456,
#  0.17403969168663025,
#  0.21412180364131927,
#  0.350058376789093,
#  0.22193334996700287,
#  0.6323979496955872,
#  0.7070599794387817,
#  0.11833975464105606,
#  1.7469773292541504,
#  0.02530585043132305,
#  0.2861570715904236,
#  0.9790132641792297,
#  0.1230693832039833,
#  0.2315182238817215,
#  0.1841873824596405,
#  0.4295799434185028,
#  0.3161374032497406,
#  0.27135515213012695,
#  0.45148077607154846,
#  0.7551791667938232,
#  0.17094847559928894,
#  0.5739890933036804,
#  0.5042654275894165,
#  1.0781465768814087,
#  0.7542142868041992,
#  0.35642576217651367,
#  0.691815197467804,
#  0.8037784099578857,
#  0.02882288582623005,
#  0.6261900663375854,
#  0.3007799983024597,
#  0.908659040927887,
#  1.129030704498291,
#  0.9413776993751526,
#  0.17091503739356995,
#  1.2909972667694092,
#  0.33504635095596313,
#  0.06710312515497208,
#  0.0861768126487732,
#  0.644539475440979,
#  0.45479339361190796,
#  0.13615788519382477,
#  0.045603662729263306,
#  0.362597793340683,
#  0.03766060248017311,
#  0.6864156126976013,
#  0.09446147829294205,
#  0.2823198437690735,
#  0.6827660202980042,
#  0.5996220707893372,
#  1.152897834777832,
#  0.27215152978897095,
#  0.17318624258041382,
#  0.38749656081199646,
#  0.22404198348522186,
#  0.24531301856040955,
#  0.0782848596572876,
#  0.2213931381702423,
#  0.054559752345085144,
#  0.383349746465683,
#  0.38883769512176514,
#  0.4712192416191101,
#  1.0291781425476074,
#  0.32694774866104126,
#  0.05847560986876488,
#  0.3457150459289551,
#  0.45072439312934875,
#  0.024281451478600502,
#  0.42556098103523254,
#  0.1804903745651245,
#  0.1664716899394989,
#  0.15919139981269836,
#  0.5006412863731384,
#  0.30931419134140015,
#  0.04637918621301651,
#  1.191685676574707,
#  0.1799643337726593,
#  1.7075252532958984,
#  0.12416121363639832,
#  0.39003419876098633,
#  0.2358272522687912,
#  0.08095933496952057,
#  0.627350389957428,
#  0.4918157756328583,
#  0.35286110639572144,
#  0.10096272826194763,
#  0.2019256055355072,
#  0.5387192964553833,
#  0.21578523516654968,
#  0.6927908062934875,
#  0.42712628841400146,
#  0.1854972243309021,
#  0.35514262318611145,
#  0.6336650848388672,
#  0.5326110124588013,
#  1.2391027212142944,
#  0.4163952171802521,
#  0.7143309712409973,
#  0.40168440341949463,
#  1.0660462379455566,
#  0.6557080745697021,
#  0.8912046551704407,
#  0.5845060348510742,
#  0.06330813467502594,
#  0.5531290769577026,
#  0.7424697279930115,
#  0.48021024465560913,
#  0.4252088963985443,
#  0.2850317656993866,
#  0.10065227746963501,
#  0.6558875441551208,
#  0.18598787486553192,
#  0.19891193509101868,
#  0.31631433963775635,
#  0.34763216972351074,
#  0.6481305360794067,
#  0.29202574491500854,
#  0.7410163283348083,
#  0.1891445815563202,
#  1.344698429107666,
#  1.0540344715118408,
#  0.49979540705680847,
#  0.19737859070301056,
#  0.27213096618652344,
#  2.0148963928222656,
#  1.0911775827407837,
#  0.031264834105968475,
#  0.6607375741004944,
#  0.6748324036598206,
#  0.663353681564331,
#  0.025189287960529327,
#  0.8806053996086121,
#  0.3629811406135559,
#  0.5740777850151062,
#  1.412137746810913,
#  0.13903702795505524,
#  0.16477468609809875,
#  0.9165040850639343,
#  0.050777874886989594,
#  0.5729115605354309,
#  0.41357070207595825,
#  0.339402437210083,
#  0.4658855199813843,
#  0.2508499026298523,
#  0.11029381304979324,
#  0.26652973890304565,
#  0.8275325298309326,
#  1.195493459701538,
#  0.09010495990514755,
#  0.045527126640081406,
#  0.3273061215877533,
#  0.23312127590179443,
#  0.15252070128917694,
#  0.1961018443107605,
#  0.2538977265357971,
#  0.27219969034194946,
#  0.3582306206226349,
#  0.6434992551803589,
#  0.5788549184799194,
#  0.06717905402183533,
#  0.3022242486476898,
#  0.23973514139652252,
#  0.11402829736471176,
#  0.3955588936805725,
#  0.10354572534561157,
#  0.14582107961177826,
#  2.0405261516571045,
#  0.43491876125335693,
#  0.3840576112270355,
#  1.1809027194976807,
#  0.6067056059837341,
#  0.1746257245540619,
#  1.283962368965149,
#  0.34900423884391785,
#  0.3821108043193817,
#  0.05083376169204712,
#  0.9521546363830566,
#  1.1449804306030273,
#  0.24180938303470612,
#  0.2670033574104309,
#  0.33165231347084045,
#  0.07220792025327682,
#  0.39823418855667114,
#  0.33222079277038574,
#  0.1636229008436203,
#  0.13716039061546326,
#  0.5731503963470459,
#  1.4979294538497925,
#  0.38913193345069885,
#  0.006661991123110056,
#  1.8273111581802368,
#  0.32411324977874756,
#  0.171964630484581,
#  0.07193702459335327,
#  0.3409974277019501,
#  0.0772324949502945,
#  0.7964116930961609,
#  0.8131759762763977,
#  0.02286434732377529,
#  0.40557661652565,
#  0.3099815547466278,
#  0.3572029173374176,
#  0.24031752347946167,
#  1.7144821882247925,
#  0.370029479265213,
#  0.11889398097991943,
#  0.051494300365448,
#  0.3633284270763397,
#  0.9025506973266602,
#  0.03026282787322998,
#  1.1473302841186523,
#  0.45217832922935486,
#  1.3136118650436401,
#  0.08271528780460358,
#  0.4273976683616638,
#  0.9854777455329895,
#  0.15878930687904358,
#  0.15603016316890717,
#  0.4999960660934448,
#  0.4354286193847656,
#  0.0850590169429779,
#  0.17121842503547668,
#  0.07508257776498795,
#  0.16756179928779602,
#  0.6951026320457458,
#  0.7834516763687134,
#  0.4712144136428833,
#  0.5950025320053101,
#  0.04667243734002113,
#  0.16306859254837036,
#  0.6196491718292236,
#  0.05220341309905052,
#  0.45633161067962646,
#  0.673188328742981,
#  0.7555077075958252,
#  0.630243718624115,
#  0.24513912200927734,
#  0.4061817526817322,
#  0.9845864176750183,
#  0.4027347266674042,
#  0.6046526432037354,
#  4.131191253662109,
#  0.29869508743286133,
#  1.8195180892944336,
#  0.6556889414787292,
#  ...]

# %%
def dense_search_image(col, query_dense_embedding, limit=10):
    search_params = {
        "metric_type": "L2",
        }
    res = client.search(
        collection_name=milvus_collection,
        data=[query_dense_embedding],
        anns_field=col,
        limit=limit,
        output_fields=["text","local_image"],
        search_params=search_params,
        
    )
    return res[0]


dense_results = dense_search_image("image_vector", result)
dense_results
# Out:
# [{'id': '453028377636111412',
#   'distance': 0.0,
#   'entity': {'local_image': 'cr_images/0670081b-90f3-7e1d-8000-fe15aab25b3a.jpg',
#    'text': 'reviewed claim: La Policía Local de Sant Joan de Moró dice que la vacuna es experimental y necesita una receta médica y un consentimiento informado\nunverified claim: 30% de medicos holandeses hacen eutanasias sin consentimiento\nClaims are not similarRelated Image: The image features a healthcare setting where a medical professional is administering a vaccine to a patient. \n\n### Main Elements:\n1. **Characters**:\n   - **Healthcare Professional**: A person wearing a white lab coat and a blue surgical mask. They are focused on the task of giving the vaccine, holding a syringe in their right hand.\n   - **Patient**: A person sitting with their left arm exposed, receiving the vaccine. They are also wearing a blue mask, indicating adherence to health protocols.\n\n2. **Setting**: The background is minimalistic, emphasizing the interaction between the healthcare professional and the patient. The focus is on the vaccination process.\n\n3. **Composition**: \n   - The healthcare professional is positioned on the left side of the image, while the patient is on the right. This creates a clear visual flow from the provider to the recipient.\n   - The use of masks on both individuals highlights the importance of safety and health measures in the context of vaccinations.\n\n### Additional Details:\n- The image likely conveys themes of health, safety, and the importance of vaccinations, especially in light of recent global health events.\n- The overall tone is professional and reassuring, aimed at promoting trust in the vaccination process.\n\nThis description captures the essence of the image and its context related to vaccination.'}},
#  {'id': '453028377656558692',
#   'distance': 0.0,
#   'entity': {'local_image': 'cr_images/0670081b-eb73-794e-8000-9a0b535f8df3.jpg',
#    'text': 'reviewed claim: La Policía Local de Sant Joan de Moró dice que la vacuna es experimental y necesita una receta médica y un consentimiento informado\nunverified claim: contrato de consentimiento para tener sexo\nClaims are not similarRelated Image: The image features a healthcare setting where a medical professional is administering a vaccine to a patient. \n\n### Main Elements:\n1. **Characters**:\n   - **Healthcare Professional**: A person wearing a white lab coat and a blue surgical mask. They are focused on the task of giving the vaccine, holding a syringe in their right hand.\n   - **Patient**: A person sitting with their left arm exposed, receiving the vaccine. They are also wearing a blue mask, indicating adherence to health protocols.\n\n2. **Setting**:\n   - The background is minimalistic, emphasizing the interaction between the healthcare professional and the patient. There are no distracting elements, allowing the viewer to focus on the vaccination process.\n\n3. **Composition**:\n   - The healthcare professional is positioned on the left side of the image, while the patient is on the right. This creates a balanced composition, with both characters engaged in the vaccination process.\n   - The use of colors is soft, with a predominance of blues and whites, which are often associated with healthcare and cleanliness.\n\n### Additional Details:\n- The image conveys a sense of care and professionalism, highlighting the importance of vaccinations in public health.\n- The presence of masks on both individuals underscores the ongoing health measures in place, likely in response to a pandemic context.\n\nOverall, the image effectively communicates a vital health message through its clear depiction of a vaccination scenario.'}},
#  {'id': '453028464482062396',
#   'distance': 0.0,
#   'entity': {'local_image': 'cr_images/0670081b-90f3-7e1d-8000-fe15aab25b3a.jpg',
#    'text': 'reviewed claim: La Policía Local de Sant Joan de Moró dice que la vacuna es experimental y necesita una receta médica y un consentimiento informado\nunverified claim: 30% de medicos holandeses hacen eutanasias sin consentimiento\nClaims are not similarRelated Image: The image features a healthcare setting where a medical professional is administering a vaccine to a patient. \n\n### Main Elements:\n1. **Characters**:\n   - **Healthcare Professional**: A person wearing a white lab coat and a blue surgical mask. They are focused on the task of giving the vaccine, holding a syringe in their right hand.\n   - **Patient**: A person sitting with their left arm exposed, receiving the vaccine. They are also wearing a blue mask, indicating adherence to health protocols.\n\n2. **Setting**: The background is minimalistic, emphasizing the interaction between the healthcare professional and the patient. The focus is on the vaccination process.\n\n3. **Composition**: \n   - The healthcare professional is positioned on the left side of the image, while the patient is on the right. This creates a clear visual flow from the provider to the recipient.\n   - The use of masks on both individuals highlights the importance of safety and health measures in the context of vaccinations.\n\n### Additional Details:\n- The image likely conveys themes of health, safety, and the importance of vaccinations, especially in light of recent global health events.\n- The overall tone is professional and reassuring, aimed at promoting trust in the vaccination process.\n\nThis description captures the essence of the image and its context related to vaccination.'}},
#  {'id': '453028464504344684',
#   'distance': 0.0,
#   'entity': {'local_image': 'cr_images/0670081b-eb73-794e-8000-9a0b535f8df3.jpg',
#    'text': 'reviewed claim: La Policía Local de Sant Joan de Moró dice que la vacuna es experimental y necesita una receta médica y un consentimiento informado\nunverified claim: contrato de consentimiento para tener sexo\nClaims are not similarRelated Image: The image features a healthcare setting where a medical professional is administering a vaccine to a patient. \n\n### Main Elements:\n1. **Characters**:\n   - **Healthcare Professional**: A person wearing a white lab coat and a blue surgical mask. They are focused on the task of giving the vaccine, holding a syringe in their right hand.\n   - **Patient**: A person sitting with their left arm exposed, receiving the vaccine. They are also wearing a blue mask, indicating adherence to health protocols.\n\n2. **Setting**:\n   - The background is minimalistic, emphasizing the interaction between the healthcare professional and the patient. There are no distracting elements, allowing the viewer to focus on the vaccination process.\n\n3. **Composition**:\n   - The healthcare professional is positioned on the left side of the image, while the patient is on the right. This creates a balanced composition, with both characters engaged in the vaccination process.\n   - The use of colors is soft, with a predominance of blues and whites, which are often associated with healthcare and cleanliness.\n\n### Additional Details:\n- The image conveys a sense of care and professionalism, highlighting the importance of vaccinations in public health.\n- The presence of masks on both individuals underscores the ongoing health measures in place, likely in response to a pandemic context.\n\nOverall, the image effectively communicates a vital health message through its clear depiction of a vaccination scenario.'}},
#  {'id': '453028377776883052',
#   'distance': 269.13397216796875,
#   'entity': {'local_image': 'cr_images/0670081d-8dc5-7128-8000-25b94c91305f.jpg',
#    'text': 'reviewed claim: See how these Muslim men lure juvenile Hindu girls in the name of love jihad\nunverified claim: españa tasa de paro juvenil mas baja de la historia\nClaims are not similarRelated Image: The image appears to be a screenshot from a social media post, likely from Facebook, featuring a video that has been labeled as "FAKE." \n\n### Main Elements:\n1. **Text Overlay**: The word "FAKE" is prominently displayed in bold red letters across the image, indicating that the content is being disputed or debunked.\n2. **User Information**: The post is attributed to a user named "Dev Gupta," with a timestamp indicating it was posted on December 7 at 21:14. There are also indications of engagement, showing 251 views and options for comments and replies.\n3. **Video Thumbnails**: The image includes several small thumbnails from the video, showing different scenes or characters. \n   - One thumbnail features a man wearing a red and white jacket, appearing to engage with someone off-screen.\n   - Another thumbnail shows a woman wearing a yellow mask, possibly speaking or reacting to the situation.\n   - Additional thumbnails may depict other characters or scenes relevant to the video\'s content.\n\n### Composition:\n- The layout is structured with the main video content on the left side, while the user information and engagement metrics are displayed at the top.\n- The background is a light gray, which helps the text and images stand out.\n- The blurred face of a person in the background suggests an attempt to protect their identity, indicating sensitivity around the content.\n\n### Context:\nThe image is related to claims about a video involving interactions with women, possibly in a controversial or misleading context, as suggested by the "FAKE" label. The overall composition emphasizes the need for scrutiny regarding the video\'s authenticity.'}},
#  {'id': '453028464624931188',
#   'distance': 269.13397216796875,
#   'entity': {'local_image': 'cr_images/0670081d-8dc5-7128-8000-25b94c91305f.jpg',
#    'text': 'reviewed claim: See how these Muslim men lure juvenile Hindu girls in the name of love jihad\nunverified claim: españa tasa de paro juvenil mas baja de la historia\nClaims are not similarRelated Image: The image appears to be a screenshot from a social media post, likely from Facebook, featuring a video that has been labeled as "FAKE." \n\n### Main Elements:\n1. **Text Overlay**: The word "FAKE" is prominently displayed in bold red letters across the image, indicating that the content is being disputed or debunked.\n2. **User Information**: The post is attributed to a user named "Dev Gupta," with a timestamp indicating it was posted on December 7 at 21:14. There are also indications of engagement, showing 251 views and options for comments and replies.\n3. **Video Thumbnails**: The image includes several small thumbnails from the video, showing different scenes or characters. \n   - One thumbnail features a man wearing a red and white jacket, appearing to engage with someone off-screen.\n   - Another thumbnail shows a woman wearing a yellow mask, possibly speaking or reacting to the situation.\n   - Additional thumbnails may depict other characters or scenes relevant to the video\'s content.\n\n### Composition:\n- The layout is structured with the main video content on the left side, while the user information and engagement metrics are displayed at the top.\n- The background is a light gray, which helps the text and images stand out.\n- The blurred face of a person in the background suggests an attempt to protect their identity, indicating sensitivity around the content.\n\n### Context:\nThe image is related to claims about a video involving interactions with women, possibly in a controversial or misleading context, as suggested by the "FAKE" label. The overall composition emphasizes the need for scrutiny regarding the video\'s authenticity.'}},
#  {'id': '453028466408825000',
#   'distance': 269.13397216796875,
#   'entity': {'local_image': 'cr_images/06700844-c9b2-77d7-8000-04581ad0bca7.jpg',
#    'text': 'reviewed claim: See how these Muslim men lure juvenile Hindu girls in the name of love jihad\nunverified claim: españa minimos historicos de paro juvenil\nClaims are not similarRelated Image: The image appears to be a screenshot from a social media post, likely from Facebook, featuring a video that has been labeled as "FAKE." \n\n### Main Elements:\n1. **Text Overlay**: The word "FAKE" is prominently displayed in bold red letters across the image, indicating that the content is being disputed or debunked.\n2. **User Information**: The post is attributed to a user named "Dev Gupta," with a timestamp indicating it was posted on December 7 at 21:14. There are also indicators of engagement, showing 251 views and options for comments and replies.\n3. **Video Thumbnails**: The image includes several small thumbnails from the video, showing different scenes or characters. \n   - One thumbnail features a man wearing a red and white jacket, appearing to engage with someone off-screen.\n   - Another thumbnail shows a woman wearing a yellow mask, possibly speaking or reacting to the situation.\n   - Additional thumbnails may depict other characters or scenes relevant to the video\'s content.\n\n### Composition:\n- The layout is structured with the main video content on the left side, while the user information and engagement metrics are displayed at the top.\n- The background is a light gray, which helps the text and images stand out.\n- The blurred face of a person in the background suggests an attempt to protect their identity, indicating sensitivity around the content.\n\n### Context:\nThe text in the post seems to discuss a controversial topic involving young women, hinting at a narrative that may be misleading or sensationalized, as suggested by the "FAKE" label. The overall composition conveys a sense of urgency and caution regarding the video\'s authenticity.'}},
#  {'id': '453028377502942032',
#   'distance': 304.2633056640625,
#   'entity': {'local_image': 'cr_images/06700818-d9dd-7ae6-8000-76794da5cd20.png',
#    'text': 'reviewed claim: Valle tendrá confinamiento total del 9 al 11 de abril de 2021\nunverified claim: 2023 tendra 366 dias\nClaims are not similarRelated Image: The image features a woman with long, wavy hair, wearing a white mask, which suggests a context related to health or safety, possibly during a pandemic. She is seated and appears to be engaged in a discussion or presentation, likely in a formal setting, given her attire and the context of the image.\n\nIn the background, there is a tweet displayed, attributed to Clara Luz Roldán González, which discusses a public health directive or recommendation. The tweet emphasizes the importance of adhering to certain guidelines and mentions a specific circular related to health measures in the Valle del Cauca region. The text suggests a focus on community safety and compliance with health protocols.\n\nThe overall composition includes a vibrant turquoise background that contrasts with the more muted tones of the woman’s clothing and the text, drawing attention to both the speaker and the message being conveyed. The layout indicates a blend of visual and textual information, likely aimed at informing the audience about health measures and encouraging compliance.'}},
#  {'id': '453028464381923160',
#   'distance': 304.2633056640625,
#   'entity': {'local_image': 'cr_images/06700818-d9dd-7ae6-8000-76794da5cd20.png',
#    'text': 'reviewed claim: Valle tendrá confinamiento total del 9 al 11 de abril de 2021\nunverified claim: 2023 tendra 366 dias\nClaims are not similarRelated Image: The image features a woman with long, wavy hair, wearing a white mask, which suggests a context related to health or safety, possibly during a pandemic. She is seated and appears to be engaged in a discussion or presentation, likely in a formal setting, given her attire and the context of the image.\n\nIn the background, there is a tweet displayed, attributed to Clara Luz Roldán González, which discusses a public health directive or recommendation. The tweet emphasizes the importance of adhering to certain guidelines and mentions a specific circular related to health measures in the Valle del Cauca region. The text suggests a focus on community safety and compliance with health protocols.\n\nThe overall composition includes a vibrant turquoise background that contrasts with the more muted tones of the woman’s clothing and the text, drawing attention to both the speaker and the message being conveyed. The layout indicates a blend of visual and textual information, likely aimed at informing the audience about health measures and encouraging compliance.'}},
#  {'id': '453028466591277678',
#   'distance': 307.2703857421875,
#   'entity': {'local_image': 'cr_images/06700848-c38d-7d69-8000-94edd92096e8.jpg',
#    'text': 'reviewed claim: El Tribunal de Cuentas investiga a Moreno Bonilla por presunta corrupción estimada en 1,7 millones\nunverified claim: tribunal de cuentas de la ue españa es el peor pais en ejecutar los fondos de la ue\nClaims are not similarRelated Image: The image appears to be a collage of news articles and headlines related to an investigation involving a person named Moreno Bonilla. The main elements of the image include:\n\n1. **Headlines**: Several headlines are prominently displayed, alluding to an investigation by the "Tribunal de Cuentas" (Court of Auditors) into Moreno Bonilla for alleged corruption valued at 1.7 million. The text is in Spanish and emphasizes the seriousness of the claims.\n\n2. **Visual Elements**: \n   - The word "BULO" (meaning "hoax" or "falsehood") is stamped across the image in bold red letters, suggesting a denial or rebuttal of the claims made in the articles.\n   - The layout includes a mix of text and images, with some articles featuring photographs of Moreno Bonilla, likely taken during public appearances or events.\n\n3. **Composition**: The articles are arranged in a grid-like format, with varying sizes and orientations. This creates a dynamic visual effect, drawing attention to the central theme of the investigation and the contrasting claim of it being a hoax.\n\n4. **Contextual Imagery**: One of the articles features a photo of Moreno Bonilla, possibly in a formal setting, which adds a personal element to the narrative. Another article may include a logo or branding related to the political context, enhancing the overall message.\n\nOverall, the image conveys a sense of controversy and public scrutiny surrounding Moreno Bonilla, while also attempting to counter the allegations with the "BULO" label.'}}]
